# %% [markdown]
# <div class="alert alert-block alert-warning">
# Employee Attrition Classification Dataset
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <!-- info, danger, warning, success -->
# Import <b> Librraries</b>
# </div>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
import joblib

# %% [markdown]
# <div class="alert alert-block alert-info">
# <!-- info, danger, warning, success -->
# <b>1.<b> Data Loading
# </div>

# %%
Dataset = pd.read_csv("test.csv")

# %% [markdown]
# <div class="alert alert-block alert-info">
# <!-- info, danger, warning, success -->
# <b>2.<b> Data Exploring
# </div>

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14900 entries, 0 to 14899
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               14900 non-null  int64
#  1   Age                       14900 non-null  int64
#  2   Gender                    14900 non-null  object
#  3   Years at Company          14900 non-null  int64
#  4   Job Role                  14900 non-null  object
#  5   Monthly Income            14900 non-null  int64
#  6   Work-Life Balance         14900 non-null  object
#  7   Job Satisfaction          14900 non-null  object
#  8   Performance Rating        14900 non-null  object
#  9   Number of Promotions      14900 non-null  int64
#  10  Overtime                  14900 non-null  object
#  11  Distance from Home        14900 non-null  int64
#  12  Education Level           14900 non-null  object
# ...

# %%
Dataset.describe()
# Out:
#         Employee ID           Age  Years at Company  Monthly Income  \
# count  14900.000000  14900.000000      14900.000000    14900.000000
# mean   37339.022081     38.385235         15.592416     7287.306040
# std    21453.129293     12.097904         11.133792     2156.737934
# min        5.000000     18.000000          1.000000     1226.000000
# 25%    18825.500000     28.000000          7.000000     5633.750000
# 50%    37433.000000     38.000000         13.000000     7332.000000
# 75%    55857.500000     49.000000         23.000000     8852.000000
# max    74471.000000     59.000000         51.000000    15063.000000
#
#        Number of Promotions  Distance from Home  Number of Dependents  \
# count          14900.000000        14900.000000          14900.000000
# mean               0.834362           49.927315              1.659329
# std                0.996511           28.702307              1.545401
# min                0.000000            1.000000              0.000000
# ...

# %%
Dataset.shape
# Out:
# (14900, 24)

# %% [markdown]
# # Determine the Null colums

# %%
Dataset.isnull().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# Company Tenure              0
# Remote Work                 0
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        0
# Attrition                   0
# dtype: int64

# %% [markdown]
# # To print rows

# %%
Dataset.head()
# Out:
#    Employee ID  Age Gender  Years at Company    Job Role  Monthly Income  \
# 0        52685   36   Male                13  Healthcare            8029
# 1        30585   35   Male                 7   Education            4563
# 2        54656   50   Male                 7   Education            5583
# 3        33442   58   Male                44       Media            5525
# 4        15667   39   Male                24   Education            4604
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent             High            Average                     1
# 1              Good             High            Average                     1
# 2              Fair             High            Average                     3
# 3              Fair        Very High               High                     0
# 4              Good             High            Average                     0
#
# ...

# %% [markdown]
# # To print bottom rows

# %%
Dataset.tail()
# Out:
#        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 14895        16243   56  Female                42  Healthcare            7830
# 14896        47175   30  Female                15   Education            3856
# 14897        12409   52    Male                 5   Education            5654
# 14898         9554   18    Male                 4   Education            5276
# 14899        73042   59  Female                48   Education            3774
#
#       Work-Life Balance Job Satisfaction Performance Rating  \
# 14895              Poor           Medium            Average
# 14896              Good           Medium            Average
# 14897              Good        Very High      Below Average
# 14898              Fair             High            Average
# 14899              Good             High      Below Average
#
#        Number of Promotions  ... Number of Dependents  Job Level Company Size  \
# ...

# %% [markdown]
# # To Print number of rows

# %%
print('rows: ', Dataset.shape[0])
# Out:
# rows:  14900

# %% [markdown]
# # To print number of colums

# %%
print('columns: ', Dataset.shape[1])
# Out:
# columns:  24

# %% [markdown]
# # Filling all null values using mean/median/mode

# %%
Dataset = Dataset.fillna(Dataset.mean)

# %%
Dataset = Dataset.fillna(Dataset.median)

# %%
Dataset = Dataset.fillna(Dataset.mode)

# %% [markdown]
# # Print datatype of each column:

# %%
Dataset.dtypes
# Out:
# Employee ID                  int64
# Age                          int64
# Gender                      object
# Years at Company             int64
# Job Role                    object
# Monthly Income               int64
# Work-Life Balance           object
# Job Satisfaction            object
# Performance Rating          object
# Number of Promotions         int64
# Overtime                    object
# Distance from Home           int64
# Education Level             object
# Marital Status              object
# Number of Dependents         int64
# Job Level                   object
# Company Size                object
# Company Tenure               int64
# Remote Work                 object
# Leadership Opportunities    object
# Innovation Opportunities    object
# Company Reputation          object
# Employee Recognition        object
# Attrition                   object
# dtype: object

# %%
features = ['Monthly Income', 'Job Satisfaction', 'Work-Life Balance']
target = 'Attrition'

X = Dataset[features]
y = Dataset[target]

# %%
y = pd.factorize(Dataset['Attrition'])[0]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <!-- info, danger, warning, success -->
# <b>3.<b> Data Pre-Processing
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <!-- info, danger, warning, success -->
# <b>3.1<b> Manage Null values
# </div>

# %% [markdown]
# # Checking null values

# %%
np.sum(pd.isnull(Dataset))
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# ...

# %% [markdown]
# # Checking unique values of specific column

# %%
Dataset["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# # Filling null values

# %%
num = Dataset["Remote Work"].mode()[0] 
Dataset["education"] = Dataset["Remote Work"].fillna(num)

# %%
numeric_cols = Dataset.select_dtypes(include=['int64', 'float64']).columns
Dataset[numeric_cols] = Dataset[numeric_cols].fillna(Dataset[numeric_cols].median())


categorical_cols = Dataset.select_dtypes(include=['object']).columns
Dataset[categorical_cols] = Dataset[categorical_cols].fillna(Dataset[categorical_cols].mode().iloc[0])

# %% [markdown]
# <div class="alert alert-block alert-success">
# <!-- info, danger, warning, success -->
# <b>3.2<b> Data Types Manage
# </div>

# %%
for col in Dataset.columns:
    if Dataset[col].dtype == "object":
        if Dataset[col].str.isdigit().all():
            Dataset[col] = Dataset[col].astype(int)

# %% [markdown]
# # Encoding Categorical Columns

# %%
label_enc = LabelEncoder()

for col in categorical_cols:
    Dataset[col] = label_enc.fit_transform(Dataset[col])

# %% [markdown]
# # Feature Scaling (Except Target Attrition)

# %%
scaler = StandardScaler()

numeric_cols = Dataset.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Target column ko scaling se nikaal do
if "Attrition" in numeric_cols:
    numeric_cols.remove("Attrition")

# Scale
Dataset[numeric_cols] = scaler.fit_transform(Dataset[numeric_cols])

# %% [markdown]
# # handling outliers

# %%
from sklearn.preprocessing import LabelEncoder

features = ['Monthly Income', 'Job Satisfaction', 'Work-Life Balance']

# Initialize encoder
le = LabelEncoder()

for col in features:
    if Dataset[col].dtype == 'object':
        Dataset[col] = le.fit_transform(Dataset[col])

# %% [markdown]
# # Splitting into x and y

# %%
 
from sklearn.preprocessing import LabelEncoder

X = Dataset[features].copy()   

le = LabelEncoder()
for col in ['Job Satisfaction', 'Work-Life Balance']:
    X.loc[:, col] = le.fit_transform(X[col])

# %%
numeric_features = ['Age', 'Years at Company', 'Monthly Income', 'Number of Promotions',
                    'Distance from Home', 'Number of Dependents', 'Company Tenure']

categorical_features = ['Job Role', 'Work-Life Balance', 'Job Satisfaction',
                        'Performance Rating', 'Overtime', 'Education Level', 'Marital Status',
                        'Job Level', 'Company Size', 'Remote Work', 'Leadership Opportunities',
                        'Innovation Opportunities', 'Company Reputation', 'Employee Recognition']
X = Dataset[numeric_features + categorical_features]
y = Dataset['Attrition']

# %% [markdown]
# # Converting Object columns into Int columns

# %%
cat_columns = x.select_dtypes(['object']).columns 
x[cat_columns] = x[cat_columns].apply(lambda x: pd.factorize(x)[0])

# %%
cat_columns = x.select_dtypes(include=['object']).columns # identify categorical colums
print(cat_columns)
# Out:
# Index([], dtype='object')

# %%
x[cat_columns] = x[cat_columns].apply(lambda col: pd.factorize(col)[0])

# %% [markdown]
# # Save preprocessed csv

# %%
Dataset.to_csv("preprocessed.csv", index=False)

print("Preprocessing Completed Successfully!")
print("Saved as: preprocessed.csv")

 
Dataset.head()
# Out:
# Preprocessing Completed Successfully!
# Saved as: preprocessed.csv
#    Employee ID       Age    Gender  Years at Company  Job Role  \
# 0     0.715350 -0.197168  0.917858         -0.232850 -0.075427
# 1    -0.314837 -0.279829  0.917858         -0.771768 -1.435207
# 2     0.807228  0.960097  0.917858         -0.771768 -1.435207
# 3    -0.181659  1.621390  0.917858          2.551560  0.604463
# 4    -1.010237  0.050818  0.917858          0.755166 -1.435207
#
#    Monthly Income  Work-Life Balance  Job Satisfaction  Performance Rating  \
# 0        0.343908          -1.560957         -0.896355           -0.737485
# 1       -1.263203           0.556800         -0.896355           -0.737485
# 2       -0.790251          -0.502079         -0.896355           -0.737485
# 3       -0.817144          -0.502079          1.566280            1.341117
# 4       -1.244192           0.556800         -0.896355           -0.737485
#
# ...

# %%
le_target = LabelEncoder()
y = le_target.fit_transform(y)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', numeric_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ]
)

X_processed = preprocessor.fit_transform(X)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <!-- info, danger, warning, success -->
# <b>4.<b> Train test and Splitting
# </div>

# %% [markdown]
# # Splitting Data into train and test

# %%
 
X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y, test_size=0.3, random_state=42, shuffle=True
)
 
print("x_train shape:", X_train.shape)
print("x_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (10430, 54)
# x_test shape: (4470, 54)
# y_train shape: (10430,)
# y_test shape: (4470,)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <!-- info, danger, warning, success -->
# <b>5.<b> Choose and Train the Model
# </div>

# %%
rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=15,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=42,
    class_weight='balanced'
)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=15,
#                        min_samples_leaf=5, min_samples_split=10,
#                        n_estimators=300, random_state=42)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <!-- info, danger, warning, success -->
# <b>6.<b> Testing & Prediction
# </div>

# %%
new_employee = pd.DataFrame([{
    'Age': 35,
    'Years at Company': 5,
    'Monthly Income': 5000,
    'Number of Promotions': 1,
    'Distance from Home': 10,
    'Number of Dependents': 2,
    'Company Tenure': 6,
    'Job Role': 'Healthcare',
    'Work-Life Balance': 'Good',
    'Job Satisfaction': 'High',
    'Performance Rating': 'Average',
    'Overtime': 'No',
    'Education Level': 'Bachelor',
    'Marital Status': 'Single',
    'Job Level': 'Entry',
    'Company Size': 'Medium',
    'Remote Work': 'No',
    'Leadership Opportunities': 'No',
    'Innovation Opportunities': 'No',
    'Company Reputation': 'Good',
    'Employee Recognition': 'Medium'
}])

# Transform and predict
new_employee_processed = preprocessor.transform(new_employee)
prediction = rf_model.predict(new_employee_processed)
prediction_label = le_target.inverse_transform(prediction)
print("\nPredicted Attrition for new employee:", prediction_label[0])
# Out:
# Predicted Attrition for new employee: 1

# %% [markdown]
# <div class="alert alert-block alert-info">
# <!-- info, danger, warning, success -->
# <b>7.<b> Accuracy Score
# </div>

# %%
y_pred = rf_model.predict(X_test)

accuracy = metrics.accuracy_score(y_test, y_pred)
print("\nRandom Forest Accuracy: {:.2f}%".format(accuracy*100))
print(metrics.classification_report(y_test, y_pred))
# Out:
# Random Forest Accuracy: 74.30%
#               precision    recall  f1-score   support
#
#            0       0.72      0.75      0.74      2128
#            1       0.77      0.73      0.75      2342
#
#     accuracy                           0.74      4470
#    macro avg       0.74      0.74      0.74      4470
# weighted avg       0.74      0.74      0.74      4470

# %% [markdown]
# <div class="alert alert-block alert-info">
# <!-- info, danger, warning, success -->
# <b>8.<b> Save Model
# </div>

# %%
joblib.dump(rf_model, 'model.pkl')
joblib.dump(preprocessor, 'preprocessor.pkl')
print("\nModel and preprocessor saved successfully!")
# Out:
# Model and preprocessor saved successfully!
